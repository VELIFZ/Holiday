# %% [markdown]
# ## Python Blackjack
# For this project you will make a Blackjack game using Python. Click <a href="http://www.hitorstand.net/strategy.php">here</a> to familiarize yourself with the the rules of the game. You won't be implementing every rule "down to the letter" with the game, but we will doing a simpler version of the game. This assignment will be given to further test your knowledge on object-oriented programming concepts.
#
# ### Rules:
#
# `1. ` The game will have two players: the Dealer and the Player. The game will start off with a deck of 52 cards. The 52 cards will consist of 4 different suits: Clubs, Diamonds, Hearts and Spades. For each suit, there will be cards numbered 1 through 13. <br>
# **Note: No wildcards will be used in the program**
#
# `2. ` When the game begins, the dealer will shuffle the deck of cards, making them randomized. After the dealer shuffles, it will deal the player 2 cards and will deal itself 2 cards from. The Player should be able to see both of their own cards, but should only be able to see one of the Dealer's cards.
#
# `3. ` The objective of the game is for the Player to count their cards after they're dealt. If they're not satisfied with the number, they have the ability to 'Hit'. A hit allows the dealer to deal the Player one additional card. The Player can hit as many times as they'd like as long as they don't 'Bust'. A bust is when the Player is dealt cards that total more than 21.
#
# `4. ` If the dealer deals the Player cards equal to 21 on the **first** deal, the Player wins. This is referred to as Blackjack. Blackjack is **NOT** the same as getting cards that equal up to 21 after the first deal. Blackjack can only be attained on the first deal.
#
# `5. ` The Player will never see the Dealer's hand until the Player chooses to 'stand'. A Stand is when the player tells the dealer to not deal it anymore cards. Once the player chooses to Stand, the Player and the Dealer will compare their hands. Whoever has the higher number wins. Keep in mind that the Dealer can also bust.

# %%
import random

suit = ['\u2662', '\u2667', '\u2664', '\u2661']
value = [i for i in range(1, 14)]          

class Card:
    def __init__(self):
        self.value = value
        self.suit = suit
    
    def __str__(self):
        return f'{self.value}{self.suit}'

class Deck:
    
    def __init__(self):
        self.deck = self.create_deck()
        self.shuffle()
    def create_deck(self):
        return [(v, s) for v in value for s in suit]
    
    def __len__ (self):
        return len(self.deck)
    
    def card_cikar(self):
        if len(self.deck) >= 2:
            return self.deck.pop()
    
    def shuffle(self):
        if len(self.deck) >= 2:
            random.shuffle(self.deck)

class Person:
    def __init__(self, oyuncu_dealer): 
        self.hand = []
        self.value = 0
        self.oyuncu_dealer = oyuncu_dealer
        
class Dealer(Person):
    
    def __init__(self):
        super().__init__('dealer')
        
    def el_goster(self):
        if len (self.hand) >= 2 :
            print(f"Dealer's hand: \nHidden, {self.hand[0]}")
        
class Player(Person):
    def __init__(self):
        super().__init__('oyuncu')
        
class BlackJack:
       
    def __init__(self):
        self.oyuncu = Player()
        self.dealer = Dealer()
          
    def game(self):
        while True:
            deck = Deck()
            self.oyuncu.hand.append(deck.card_cikar())
            self.oyuncu.hand.append(deck.card_cikar())
            self.dealer.hand.append(deck.card_cikar())
            self.dealer.hand.append(deck.card_cikar())
            print(f"Player's hand: \n{self.oyuncu.hand}")
            self.dealer.el_goster()
        
            choice = input("Whoul you like to hit or stick? Enter 'h' or 's', please.\n").lower()

            if choice == 'h':
                self.oyuncu.hand.append(deck.card_cikar())
            elif choice == 's':
                self.stand()
                break
            else:
                print('Please choose a valid option.')
       
    
    
    def toplami_goster(self):
        self.player_total = 0
        self.dealer_total = 0
        
        for i in self.oyuncu.hand:
            self.player_total += i[0] #self.oyuncu.hand[i][0]
        print(f'Player\'s total: {self.player_total}')

        for i in self.dealer.hand:
            self.dealer_total += i[0] #self.dealer.hand[i][0]
        print(f'Dealer/s total: {self.dealer_total}')
            
    def stand(self):
        self.toplami_goster()
        self.busts()
    
    def busts(self):
        is_bust = False      
        while True:
            if self.player_total > 21:
                print('Player has busted!')
                is_busted = True
                break
            elif self.dealer_total > 21:
                print('Dealer has busted')
                is_busted = True
                break
    
    def kazan(self):
        if player_total == 21 and len(player) == 2:
            print('Blackjack!')
        elif dealer_total == 21 and len(dealer) == 2:
            print('Blackjack!')
                
    def win (self):
        if is_bust == True:    
            if player_total > dealer_total:
                print('Player wins!')
            elif dealer_total > player_total:
                print('Dealer wins!')
            elif player_total == dealer_total:
                print("It's a tie!")


play = BlackJack()
play.game()
# Out:
# Player's hand:
# [(5, '♤'), (1, '♤')]
# Dealer's hand:
# Hidden, (5, '♢')
# Whoul you like to hit or stick? Enter 'h' or 's', please.
# h
# Player's hand:
# [(5, '♤'), (1, '♤'), (7, '♧'), (11, '♧'), (10, '♡')]
# Dealer's hand:
# Hidden, (5, '♢')
# Whoul you like to hit or stick? Enter 'h' or 's', please.
# s
# Player's total: 34
# Dealer/s total: 20
# Player has busted!
